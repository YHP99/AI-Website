# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

model = tf.global_variables_initializer()

data = read_csv('price data.csv', sep=',')

xy = np.array(data, dtype=np.float32)

x_data = xy[:, 1:-1]
y_data = xy[:, [-1]]

X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

H = tf.matmul(X, W) + b

cost = tf.reduce_mean(tf.square(H - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, H, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 배추 가격: ", hypo_[0])
# Out:
# # 0  손실 비용:  12833570.0
# - 배추 가격:  [1.9103367]
# # 500  손실 비용:  4203439.5
# - 배추 가격:  [-283.6118]
# # 1000  손실 비용:  3795018.8
# - 배추 가격:  [26.990585]
# # 1500  손실 비용:  3475988.2
# - 배추 가격:  [310.0515]
# # 2000  손실 비용:  3225036.2
# - 배추 가격:  [561.5446]
# # 2500  손실 비용:  3027168.8
# - 배추 가격:  [784.98254]
# # 3000  손실 비용:  2870912.8
# - 배추 가격:  [983.5484]
# # 3500  손실 비용:  2747390.2
# - 배추 가격:  [1160.0503]
# # 4000  손실 비용:  2649672.2
# - 배추 가격:  [1316.9658]
# # 4500  손실 비용:  2572327.0
# - 배추 가격:  [1456.4885]
# # 5000  손실 비용:  2511079.5
# - 배추 가격:  [1580.5608]
# # 5500  손실 비용:  2462558.5
# - 배추 가격:  [1690.9032]
# # 6000  손실 비용:  2424104.8
# - 배추 가격:  [1789.0408]
# # 6500  손실 비용:  2393614.2
# - 배추 가격:  [1876.3313]
# # 7000  손실 비용:  2369425.5
# - 배추 가격:  [1953.9756]
# # 7500  손실 비용:  2350222.0
# - 배추 가격:  [2023.0432]
# # 8000  손실 비용:  2334965.0
# - 배추 가격:  [2084.4827]
# # 8500  손실 비용:  2322830.0
# - 배추 가격:  [2139.1392]
# # 9000  손실 비용:  2313166.2
# - 배추 가격:  [2187.7622]
# # 9500  손실 비용:  2305458.5
# - 배추 가격:  [2231.018]
# # 10000  손실 비용:  2299298.5
# - 배추 가격:  [2269.5015]
# # 10500  손실 비용:  2294363.5
# - 배추 가격:  [2303.7385]
# # 11000  손실 비용:  2290398.8
# - 배추 가격:  [2334.1987]
# # 11500  손실 비용:  2287200.5
# - 배추 가격:  [2361.298]
# # 12000  손실 비용:  2284610.0
# - 배추 가격:  [2385.4092]
# # 12500  손실 비용:  2282499.8
# - 배추 가격:  [2406.8613]
# # 13000  손실 비용:  2280770.8
# - 배추 가격:  [2425.949]
# # 13500  손실 비용:  2279342.2
# - 배추 가격:  [2442.9326]
# # 14000  손실 비용:  2278152.8
# - 배추 가격:  [2458.0427]
# # 14500  손실 비용:  2277151.8
# - 배추 가격:  [2471.489]
# # 15000  손실 비용:  2276300.5
# - 배추 가격:  [2483.4539]
# # 15500  손실 비용:  2275566.2
# - 배추 가격:  [2494.101]
# # 16000  손실 비용:  2274927.2
# - 배추 가격:  [2503.5747]
# # 16500  손실 비용:  2274361.8
# - 배추 가격:  [2512.006]
# # 17000  손실 비용:  2273855.0
# - 배추 가격:  [2519.5095]
# # 17500  손실 비용:  2273394.5
# - 배추 가격:  [2526.188]
# # 18000  손실 비용:  2272971.5
# - 배추 가격:  [2532.132]
# # 18500  손실 비용:  2272576.8
# - 배추 가격:  [2537.421]
# # 19000  손실 비용:  2272206.0
# - 배추 가격:  [2542.1313]
# # 19500  손실 비용:  2271853.8
# - 배추 가격:  [2546.3225]
# # 20000  손실 비용:  2271515.8
# - 배추 가격:  [2550.054]
# # 20500  손실 비용:  2271189.0
# - 배추 가격:  [2553.3772]
# # 21000  손실 비용:  2270872.0
# - 배추 가격:  [2556.336]
# # 21500  손실 비용:  2270562.2
# - 배추 가격:  [2558.969]
# # 22000  손실 비용:  2270258.2
# - 배추 가격:  [2561.3167]
# # 22500  손실 비용:  2269958.8
# - 배추 가격:  [2563.4038]
# # 23000  손실 비용:  2269663.2
# - 배추 가격:  [2565.2688]
# # 23500  손실 비용:  2269370.2
# - 배추 가격:  [2566.9243]
# # 24000  손실 비용:  2269080.2
# - 배추 가격:  [2568.4019]
# # 24500  손실 비용:  2268792.2
# - 배추 가격:  [2569.7197]
# # 25000  손실 비용:  2268505.5
# - 배추 가격:  [2570.8933]
# # 25500  손실 비용:  2268220.0
# - 배추 가격:  [2571.9395]
# # 26000  손실 비용:  2267935.5
# - 배추 가격:  [2572.878]
# # 26500  손실 비용:  2267652.5
# - 배추 가격:  [2573.7166]
# # 27000  손실 비용:  2267370.0
# - 배추 가격:  [2574.4539]
# # 27500  손실 비용:  2267087.8
# - 배추 가격:  [2575.109]
# # 28000  손실 비용:  2266806.2
# - 배추 가격:  [2575.7168]
# # 28500  손실 비용:  2266525.2
# - 배추 가격:  [2576.2473]
# # 29000  손실 비용:  2266245.2
# - 배추 가격:  [2576.7317]
# # 29500  손실 비용:  2265964.5
# - 배추 가격:  [2577.1602]
# # 30000  손실 비용:  2265684.2
# - 배추 가격:  [2577.5298]
# # 30500  손실 비용:  2265404.8
# - 배추 가격:  [2577.872]
# # 31000  손실 비용:  2265126.0
# - 배추 가격:  [2578.2012]
# # 31500  손실 비용:  2264847.5
# - 배추 가격:  [2578.4497]
# # 32000  손실 비용:  2264568.2
# - 배추 가격:  [2578.692]
# # 32500  손실 비용:  2264289.8
# - 배추 가격:  [2578.9346]
# # 33000  손실 비용:  2264011.5
# - 배추 가격:  [2579.1704]
# # 33500  손실 비용:  2263732.8
# - 배추 가격:  [2579.3594]
# # 34000  손실 비용:  2263454.5
# - 배추 가격:  [2579.494]
# # 34500  손실 비용:  2263177.0
# - 배추 가격:  [2579.6228]
# # 35000  손실 비용:  2262900.2
# - 배추 가격:  [2579.751]
# # 35500  손실 비용:  2262623.8
# - 배추 가격:  [2579.879]
# # 36000  손실 비용:  2262347.0
# - 배추 가격:  [2580.0068]
# # 36500  손실 비용:  2262070.0
# - 배추 가격:  [2580.1345]
# # 37000  손실 비용:  2261793.8
# - 배추 가격:  [2580.2625]
# # 37500  손실 비용:  2261517.0
# - 배추 가격:  [2580.3896]
# # 38000  손실 비용:  2261240.8
# - 배추 가격:  [2580.5125]
# # 38500  손실 비용:  2260964.0
# - 배추 가격:  [2580.5598]
# # 39000  손실 비용:  2260687.8
# - 배추 가격:  [2580.5974]
# # 39500  손실 비용:  2260411.8
# - 배추 가격:  [2580.6345]
# # 40000  손실 비용:  2260136.8
# - 배추 가격:  [2580.671]
# # 40500  손실 비용:  2259861.8
# - 배추 가격:  [2580.7039]
# # 41000  손실 비용:  2259587.8
# - 배추 가격:  [2580.7368]
# # 41500  손실 비용:  2259312.8
# - 배추 가격:  [2580.7693]
# # 42000  손실 비용:  2259038.5
# - 배추 가격:  [2580.8018]
# # 42500  손실 비용:  2258764.5
# - 배추 가격:  [2580.835]
# # 43000  손실 비용:  2258489.8
# - 배추 가격:  [2580.8684]
# # 43500  손실 비용:  2258216.0
# - 배추 가격:  [2580.9016]
# # 44000  손실 비용:  2257942.0
# - 배추 가격:  [2580.935]
# # 44500  손실 비용:  2257668.8
# - 배추 가격:  [2580.968]
# # 45000  손실 비용:  2257394.5
# - 배추 가격:  [2581.0017]
# # 45500  손실 비용:  2257121.0
# - 배추 가격:  [2581.0352]
# # 46000  손실 비용:  2256848.5
# - 배추 가격:  [2581.0684]
# # 46500  손실 비용:  2256575.2
# - 배추 가격:  [2581.1018]
# # 47000  손실 비용:  2256302.2
# - 배추 가격:  [2581.1353]
# # 47500  손실 비용:  2256029.8
# - 배추 가격:  [2581.1692]
# # 48000  손실 비용:  2255758.0
# - 배추 가격:  [2581.2021]
# # 48500  손실 비용:  2255487.0
# - 배추 가격:  [2581.236]
# # 49000  손실 비용:  2255215.5
# - 배추 가격:  [2581.2705]
# # 49500  손실 비용:  2254944.2
# - 배추 가격:  [2581.3074]
# # 50000  손실 비용:  2254673.0
# - 배추 가격:  [2581.3452]
# # 50500  손실 비용:  2254402.0
# - 배추 가격:  [2581.3843]
# # 51000  손실 비용:  2254131.2
# - 배추 가격:  [2581.4263]
# # 51500  손실 비용:  2253860.8
# - 배추 가격:  [2581.4688]
# # 52000  손실 비용:  2253590.0
# - 배추 가격:  [2581.5115]
# # 52500  손실 비용:  2253320.0
# - 배추 가격:  [2581.5576]
# # 53000  손실 비용:  2253049.8
# - 배추 가격:  [2581.6035]
# # 53500  손실 비용:  2252779.2
# - 배추 가격:  [2581.65]
# # 54000  손실 비용:  2252509.2
# - 배추 가격:  [2581.6963]
# # 54500  손실 비용:  2252239.0
# - 배추 가격:  [2581.746]
# # 55000  손실 비용:  2251970.2
# - 배추 가격:  [2581.792]
# # 55500  손실 비용:  2251702.0
# - 배추 가격:  [2581.8367]
# # 56000  손실 비용:  2251433.5
# - 배추 가격:  [2581.8809]
# # 56500  손실 비용:  2251164.5
# - 배추 가격:  [2581.9282]
# # 57000  손실 비용:  2250896.8
# - 배추 가격:  [2581.9763]
# # 57500  손실 비용:  2250628.8
# - 배추 가격:  [2582.0247]
# # 58000  손실 비용:  2250360.5
# - 배추 가격:  [2582.073]
# # 58500  손실 비용:  2250093.2
# - 배추 가격:  [2582.1182]
# # 59000  손실 비용:  2249826.8
# - 배추 가격:  [2582.1606]
# # 59500  손실 비용:  2249560.0
# - 배추 가격:  [2582.2046]
# # 60000  손실 비용:  2249294.0
# - 배추 가격:  [2582.2546]
# # 60500  손실 비용:  2249027.8
# - 배추 가격:  [2582.3052]
# # 61000  손실 비용:  2248761.8
# - 배추 가격:  [2582.3557]
# # 61500  손실 비용:  2248495.8
# - 배추 가격:  [2582.406]
# # 62000  손실 비용:  2248229.2
# - 배추 가격:  [2582.4563]
# # 62500  손실 비용:  2247963.8
# - 배추 가격:  [2582.4915]
# # 63000  손실 비용:  2247698.5
# - 배추 가격:  [2582.5244]
# # 63500  손실 비용:  2247432.5
# - 배추 가격:  [2582.5579]
# # 64000  손실 비용:  2247167.2
# - 배추 가격:  [2582.5913]
# # 64500  손실 비용:  2246901.8
# - 배추 가격:  [2582.6248]
# # 65000  손실 비용:  2246636.5
# - 배추 가격:  [2582.6582]
# # 65500  손실 비용:  2246371.5
# - 배추 가격:  [2582.692]
# # 66000  손실 비용:  2246106.0
# - 배추 가격:  [2582.726]
# # 66500  손실 비용:  2245841.2
# - 배추 가격:  [2582.7593]
# # 67000  손실 비용:  2245576.5
# - 배추 가격:  [2582.7937]
# # 67500  손실 비용:  2245312.2
# - 배추 가격:  [2582.8274]
# # 68000  손실 비용:  2245048.0
# - 배추 가격:  [2582.8613]
# # 68500  손실 비용:  2244782.8
# - 배추 가격:  [2582.8955]
# # 69000  손실 비용:  2244519.2
# - 배추 가격:  [2582.9294]
# # 69500  손실 비용:  2244254.8
# - 배추 가격:  [2582.9634]
# # 70000  손실 비용:  2243990.8
# - 배추 가격:  [2582.9993]
# # 70500  손실 비용:  2243726.8
# - 배추 가격:  [2583.0461]
# # 71000  손실 비용:  2243463.0
# - 배추 가격:  [2583.093]
# # 71500  손실 비용:  2243198.5
# - 배추 가격:  [2583.1387]
# # 72000  손실 비용:  2242935.5
# - 배추 가격:  [2583.1838]
# # 72500  손실 비용:  2242671.5
# - 배추 가격:  [2583.2253]
# # 73000  손실 비용:  2242408.5
# - 배추 가격:  [2583.2651]
# # 73500  손실 비용:  2242146.8
# - 배추 가격:  [2583.301]
# # 74000  손실 비용:  2241885.5
# - 배추 가격:  [2583.332]
# # 74500  손실 비용:  2241624.8
# - 배추 가격:  [2583.3596]
# # 75000  손실 비용:  2241364.0
# - 배추 가격:  [2583.3867]
# # 75500  손실 비용:  2241103.0
# - 배추 가격:  [2583.4143]
# # 76000  손실 비용:  2240843.0
# - 배추 가격:  [2583.4417]
# # 76500  손실 비용:  2240582.5
# - 배추 가격:  [2583.4653]
# # 77000  손실 비용:  2240321.5
# - 배추 가격:  [2583.487]
# # 77500  손실 비용:  2240062.5
# - 배추 가격:  [2583.509]
# # 78000  손실 비용:  2239801.8
# - 배추 가격:  [2583.5312]
# # 78500  손실 비용:  2239541.8
# - 배추 가격:  [2583.5535]
# # 79000  손실 비용:  2239282.0
# - 배추 가격:  [2583.5745]
# # 79500  손실 비용:  2239022.5
# - 배추 가격:  [2583.5913]
# # 80000  손실 비용:  2238763.0
# - 배추 가격:  [2583.608]
# # 80500  손실 비용:  2238503.5
# - 배추 가격:  [2583.625]
# # 81000  손실 비용:  2238244.0
# - 배추 가격:  [2583.6414]
# # 81500  손실 비용:  2237985.0
# - 배추 가격:  [2583.6584]
# # 82000  손실 비용:  2237725.8
# - 배추 가격:  [2583.675]
# # 82500  손실 비용:  2237466.2
# - 배추 가격:  [2583.6912]
# # 83000  손실 비용:  2237207.8
# - 배추 가격:  [2583.7024]
# # 83500  손실 비용:  2236949.0
# - 배추 가격:  [2583.714]
# # 84000  손실 비용:  2236690.2
# - 배추 가격:  [2583.7253]
# # 84500  손실 비용:  2236431.5
# - 배추 가격:  [2583.737]
# # 85000  손실 비용:  2236173.8
# - 배추 가격:  [2583.7483]
# # 85500  손실 비용:  2235914.5
# - 배추 가격:  [2583.7598]
# # 86000  손실 비용:  2235655.8
# - 배추 가격:  [2583.7715]
# # 86500  손실 비용:  2235397.8
# - 배추 가격:  [2583.7827]
# # 87000  손실 비용:  2235139.8
# - 배추 가격:  [2583.7942]
# # 87500  손실 비용:  2234882.0
# - 배추 가격:  [2583.804]
# # 88000  손실 비용:  2234624.2
# - 배추 가격:  [2583.8103]
# # 88500  손실 비용:  2234366.0
# - 배추 가격:  [2583.827]
# # 89000  손실 비용:  2234108.8
# - 배추 가격:  [2583.8608]
# # 89500  손실 비용:  2233851.2
# - 배추 가격:  [2583.8953]
# # 90000  손실 비용:  2233593.8
# - 배추 가격:  [2583.9297]
# # 90500  손실 비용:  2233337.2
# - 배추 가격:  [2583.9634]
# # 91000  손실 비용:  2233082.8
# - 배추 가격:  [2583.997]
# # 91500  손실 비용:  2232828.2
# - 배추 가격:  [2584.0308]
# # 92000  손실 비용:  2232573.5
# - 배추 가격:  [2584.064]
# # 92500  손실 비용:  2232319.8
# - 배추 가격:  [2584.0981]
# # 93000  손실 비용:  2232065.5
# - 배추 가격:  [2584.1313]
# # 93500  손실 비용:  2231811.5
# - 배추 가격:  [2584.1655]
# # 94000  손실 비용:  2231557.2
# - 배추 가격:  [2584.1997]
# # 94500  손실 비용:  2231303.2
# - 배추 가격:  [2584.234]
# # 95000  손실 비용:  2231049.2
# - 배추 가격:  [2584.268]
# # 95500  손실 비용:  2230796.0
# - 배추 가격:  [2584.3022]
# # 96000  손실 비용:  2230542.2
# - 배추 가격:  [2584.336]
# # 96500  손실 비용:  2230288.8
# - 배추 가격:  [2584.3699]
# # 97000  손실 비용:  2230035.2
# - 배추 가격:  [2584.4038]
# # 97500  손실 비용:  2229782.2
# - 배추 가격:  [2584.4382]
# # 98000  손실 비용:  2229529.5
# - 배추 가격:  [2584.4727]
# # 98500  손실 비용:  2229276.2
# - 배추 가격:  [2584.5073]
# # 99000  손실 비용:  2229023.2
# - 배추 가격:  [2584.542]
# # 99500  손실 비용:  2228770.2
# - 배추 가격:  [2584.5764]
# # 100000  손실 비용:  2228518.2
# - 배추 가격:  [2584.6104]

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print("학습된 모델을 저장했습니다.")
# Out:
# 학습된 모델을 저장했습니다.
